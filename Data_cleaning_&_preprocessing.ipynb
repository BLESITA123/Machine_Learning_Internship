# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#import data
df=pd.read_csv("healthcare-dataset-stroke-data.csv")
print(df)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# ...

# %%
#data inspection
#head()--get top 5 rows
df.head() #by default 5 rows
print(df.head(3))
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1

# %%
#tail()--to get bottom 5 rows
print(df.tail())
print("------")
print(df.tail(3))
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
# ...

# %%
#sample()--to get random rows--defalut 1 row
print(df.sample())
print(df.sample(4))
# Out:
#         id  gender   age  hypertension  heart_disease ever_married work_type  \
# 395  23462  Female  17.0             0              0           No   Private
#
#     Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 395          Urban              87.52  39.2   never smoked       0
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 3121  60533  Female  23.0             0              0           No   Private
# 3183  15020  Female  37.0             0              0           No  Govt_job
# 3451  14912  Female  42.0             0              0          Yes   Private
# 3278  21834  Female  36.0             0              0          Yes   Private
#
#      Residence_type  avg_glucose_level   bmi smoking_status  stroke
# 3121          Rural              91.95  23.0        Unknown       0
# 3183          Rural              76.21  20.4        Unknown       0
# 3451          Rural              80.00  27.5   never smoked       0
# ...

# %%
#shape--to get total rows and columns
print(df.shape)
# Out:
# (5110, 12)

# %%
#describe---to get statistical measures of numeric columns
print(df.describe())
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
#info()---to get overall informations of the dataset
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB
# None

# %%
#dtypes--datatypes of every column
print(df.dtypes)
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
#columns -- to get column names
print(df.columns)
# Out:
# Index(['id', 'gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
#checking null values
print(df.isnull().sum())
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
#textual column--ffill(),bfill(),fill()
#numeric columns--mean(),median(),mode()
print(df['bmi'].mean())
print(df['bmi'].fillna(df['bmi'].mean(),inplace=True))
print(df)
# Out:
# 28.893236911794663
# None
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# ...

# %%
print(df.isnull().sum())
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %%
#filtering

#people with private worktype
#people who have stroke
#people who have Hypertension and stroke
#people who have heart disease and stroke
#people who live in rural, have heart disease and have stroke
#people who is children and have hypertension and stroke

# %%
print(df[df['work_type']=='Private'])
# Out:
#          id  gender   age  hypertension  heart_disease ever_married work_type  \
# 0      9046    Male  67.0             0              1          Yes   Private
# 2     31112    Male  80.0             0              1          Yes   Private
# 3     60182  Female  49.0             0              0          Yes   Private
# 5     56669    Male  81.0             0              0          Yes   Private
# 6     53882    Male  74.0             1              1          Yes   Private
# ...     ...     ...   ...           ...            ...          ...       ...
# 5101  36901  Female  45.0             0              0          Yes   Private
# 5102  45010  Female  57.0             0              0          Yes   Private
# 5103  22127  Female  18.0             0              0           No   Private
# 5105  18234  Female  80.0             1              0          Yes   Private
# 5108  37544    Male  51.0             0              0          Yes   Private
#
# ...

# %%
stroke_people = df[df['stroke'] == 1]
print(stroke_people)
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 0     9046    Male  67.0             0              1          Yes
# 1    51676  Female  61.0             0              0          Yes
# 2    31112    Male  80.0             0              1          Yes
# 3    60182  Female  49.0             0              0          Yes
# 4     1665  Female  79.0             1              0          Yes
# ..     ...     ...   ...           ...            ...          ...
# 244  17739    Male  57.0             0              0          Yes
# 245  49669  Female  14.0             0              0           No
# 246  27153  Female  75.0             0              0          Yes
# 247  34060    Male  71.0             1              0          Yes
# 248  43424  Female  78.0             0              0          Yes
#
#          work_type Residence_type  avg_glucose_level        bmi  \
# 0          Private          Urban             228.69  36.600000
# ...

# %%
ht_stroke = df[(df['hypertension'] == 1) & (df['stroke'] == 1)]
print(ht_stroke)
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 4     1665  Female  79.0             1              0          Yes
# 6    53882    Male  74.0             1              1          Yes
# 10   12109  Female  81.0             1              0          Yes
# 15   58202  Female  50.0             1              0          Yes
# 17   34120    Male  75.0             1              0          Yes
# ..     ...     ...   ...           ...            ...          ...
# 229  69959  Female  80.0             1              0           No
# 233  23368  Female  77.0             1              0          Yes
# 238   1836  Female  51.0             1              0          Yes
# 243  40460  Female  68.0             1              1          Yes
# 247  34060    Male  71.0             1              0          Yes
#
#          work_type Residence_type  avg_glucose_level        bmi  \
# 4    Self-employed          Rural             174.12  24.000000
# ...

# %%
heart_stroke = df[(df['heart_disease'] == 1) & (df['stroke'] == 1)]
print(heart_stroke)
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 0     9046    Male  67.0             0              1          Yes
# 2    31112    Male  80.0             0              1          Yes
# 6    53882    Male  74.0             1              1          Yes
# 11   12095  Female  61.0             0              1          Yes
# 13    8213    Male  78.0             0              1          Yes
# 14    5317  Female  79.0             0              1          Yes
# 16   56112    Male  64.0             0              1          Yes
# 19   25226    Male  57.0             0              1           No
# 23   64778    Male  82.0             0              1          Yes
# 28   54827    Male  69.0             0              1          Yes
# 33   54401    Male  80.0             0              1          Yes
# 35     712  Female  82.0             1              1           No
# 42   61960    Male  82.0             0              1          Yes
# ...

# %%
rural_heart_stroke = df[
    (df['Residence_type'] == 'Rural') &
    (df['heart_disease'] == 1) &
    (df['stroke'] == 1)
]
print(rural_heart_stroke)
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 2    31112    Male  80.0             0              1          Yes
# 6    53882    Male  74.0             1              1          Yes
# 11   12095  Female  61.0             0              1          Yes
# 23   64778    Male  82.0             0              1          Yes
# 35     712  Female  82.0             1              1           No
# 52   59190  Female  79.0             0              1          Yes
# 55   25831    Male  63.0             0              1          Yes
# 75   66159  Female  80.0             0              1          Yes
# 86    3253    Male  61.0             0              1          Yes
# 87   71796  Female  70.0             0              1          Yes
# 97   56841    Male  58.0             0              1          Yes
# 103   4712  Female  81.0             0              1          Yes
# 110  56546    Male  79.0             0              1          Yes
# ...

# %%
children_ht_stroke = df[(df['age'] < 18)]
print(children_ht_stroke)
# Out:
#          id  gender    age  hypertension  heart_disease ever_married  \
# 162   69768  Female   1.32             0              0           No
# 245   49669  Female  14.00             0              0           No
# 249   30669    Male   3.00             0              0           No
# 251   16523  Female   8.00             0              0           No
# 253   46136    Male  14.00             0              0           No
# ...     ...     ...    ...           ...            ...          ...
# 5089  56714  Female   0.72             0              0           No
# 5094  28048    Male  13.00             0              0           No
# 5095  68598    Male   1.08             0              0           No
# 5098    579    Male   9.00             0              0           No
# 5104  14180  Female  13.00             0              0           No
#
#          work_type Residence_type  avg_glucose_level        bmi  \
# 162       children          Urban              70.37  28.893237
# ...

# %%
children_ht_stroke = df[ (df['hypertension'] == 1) ]
print(children_ht_stroke)
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 4      1665  Female  79.0             1              0          Yes
# 6     53882    Male  74.0             1              1          Yes
# 10    12109  Female  81.0             1              0          Yes
# 15    58202  Female  50.0             1              0          Yes
# 17    34120    Male  75.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5088  22190  Female  64.0             1              0          Yes
# 5091   6369    Male  59.0             1              0          Yes
# 5093  32235  Female  45.0             1              0          Yes
# 5100  68398    Male  82.0             1              0          Yes
# 5105  18234  Female  80.0             1              0          Yes
#
#           work_type Residence_type  avg_glucose_level        bmi  \
# 4     Self-employed          Rural             174.12  24.000000
# ...

# %%
children_ht_stroke = df[(df['stroke'] == 1)]
print(children_ht_stroke)
# Out:
#         id  gender   age  hypertension  heart_disease ever_married  \
# 0     9046    Male  67.0             0              1          Yes
# 1    51676  Female  61.0             0              0          Yes
# 2    31112    Male  80.0             0              1          Yes
# 3    60182  Female  49.0             0              0          Yes
# 4     1665  Female  79.0             1              0          Yes
# ..     ...     ...   ...           ...            ...          ...
# 244  17739    Male  57.0             0              0          Yes
# 245  49669  Female  14.0             0              0           No
# 246  27153  Female  75.0             0              0          Yes
# 247  34060    Male  71.0             1              0          Yes
# 248  43424  Female  78.0             0              0          Yes
#
#          work_type Residence_type  avg_glucose_level        bmi  \
# 0          Private          Urban             228.69  36.600000
# ...

# %%
children_ht_stroke = df[(df['age'] < 18) & (df['hypertension'] == 1) & (df['stroke'] == 1)]
print(children_ht_stroke)
# Out:
# Empty DataFrame
# Columns: [id, gender, age, hypertension, heart_disease, ever_married, work_type, Residence_type, avg_glucose_level, bmi, smoking_status, stroke]
# Index: []

# %%
print(df['gender'].unique())
print(df['gender'].value_counts())
# Out:
# ['Male' 'Female' 'Other']
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64

# %%
#visualization
#gender distribution graph--bar plot

a=df['gender'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.bar(x,y)
plt.show()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64
# Index(['Female', 'Male', 'Other'], dtype='object', name='gender')

# %%
a=df['gender'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.pie(y,labels=x)
plt.show()
# Out:
# gender
# Female    2994
# Male      2115
# Other        1
# Name: count, dtype: int64
# Index(['Female', 'Male', 'Other'], dtype='object', name='gender')

# %%
print(df['age'].unique())
print(df['age'].value_counts())
# Out:
# [6.70e+01 6.10e+01 8.00e+01 4.90e+01 7.90e+01 8.10e+01 7.40e+01 6.90e+01
#  5.90e+01 7.80e+01 5.40e+01 5.00e+01 6.40e+01 7.50e+01 6.00e+01 5.70e+01
#  7.10e+01 5.20e+01 8.20e+01 6.50e+01 5.80e+01 4.20e+01 4.80e+01 7.20e+01
#  6.30e+01 7.60e+01 3.90e+01 7.70e+01 7.30e+01 5.60e+01 4.50e+01 7.00e+01
#  6.60e+01 5.10e+01 4.30e+01 6.80e+01 4.70e+01 5.30e+01 3.80e+01 5.50e+01
#  1.32e+00 4.60e+01 3.20e+01 1.40e+01 3.00e+00 8.00e+00 3.70e+01 4.00e+01
#  3.50e+01 2.00e+01 4.40e+01 2.50e+01 2.70e+01 2.30e+01 1.70e+01 1.30e+01
#  4.00e+00 1.60e+01 2.20e+01 3.00e+01 2.90e+01 1.10e+01 2.10e+01 1.80e+01
#  3.30e+01 2.40e+01 3.40e+01 3.60e+01 6.40e-01 4.10e+01 8.80e-01 5.00e+00
#  2.60e+01 3.10e+01 7.00e+00 1.20e+01 6.20e+01 2.00e+00 9.00e+00 1.50e+01
#  2.80e+01 1.00e+01 1.80e+00 3.20e-01 1.08e+00 1.90e+01 6.00e+00 1.16e+00
#  1.00e+00 1.40e+00 1.72e+00 2.40e-01 1.64e+00 1.56e+00 7.20e-01 1.88e+00
#  1.24e+00 8.00e-01 4.00e-01 8.00e-02 1.48e+00 5.60e-01 4.80e-01 1.60e-01]
# age
# 78.00    102
# ...

# %%
a=df['age'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.bar(x,y)
plt.show()
# Out:
# age
# 78.00    102
# 57.00     95
# 52.00     90
# 54.00     87
# 51.00     86
#         ...
# 1.40       3
# 0.48       3
# 0.16       3
# 0.40       2
# 0.08       2
# Name: count, Length: 104, dtype: int64
# Index([78.0, 57.0, 52.0, 54.0, 51.0, 45.0, 79.0, 53.0, 55.0, 50.0,
#        ...
#         1.0, 1.56, 1.16, 0.64,  0.8,  1.4, 0.48, 0.16,  0.4, 0.08],
#       dtype='float64', name='age', length=104)

# %%
a=df['hypertension'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
print(y)
plt.bar(x,y)
plt.title("Patient with Hypertension",fontdict={'family':'Serif','color':'purple','weight':'bold','size':20})
plt.xlabel("Hypertension Status (0 = No, 1 = Yes)",fontdict={'family':'Serif','color':'green','weight':'bold'})
plt.ylabel("Number of Patients",fontdict={'family':'Serif','color':'green','weight':'bold'})
plt.show()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64
# Index([0, 1], dtype='int64', name='hypertension')
# [4612  498]

# %%
a=df['hypertension'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.pie(y,labels=x)
plt.title("Patient with Hypertension",fontdict={'family':'Serif','color':'purple','weight':'bold','size':20})
# plt.xlabel("Hypertension Status (0 = No, 1 = Yes)",fontdict={'family':'Serif','color':'green','weight':'bold'})
# plt.ylabel("Number of Patients",fontdict={'family':'Serif','color':'green','weight':'bold'})
plt.show()
# Out:
# hypertension
# 0    4612
# 1     498
# Name: count, dtype: int64
# Index([0, 1], dtype='int64', name='hypertension')

# %%
a=df['heart_disease'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.bar(x,y)
plt.title("Heart Disease Distribution Among Patients",fontdict={'family':'Serif','weight':'bold','size':18})
plt.xlabel("Heart Disease Status (0 = No, 1 = Yes)")
plt.ylabel("Number of Patients")
plt.show()
# Out:
# heart_disease
# 0    4834
# 1     276
# Name: count, dtype: int64
# Index([0, 1], dtype='int64', name='heart_disease')

# %%
a=df['heart_disease'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.pie(y,labels=x)
plt.title("Heart Disease Distribution Among Patients",fontdict={'family':'Serif','weight':'bold','size':18})
plt.show()
# Out:
# heart_disease
# 0    4834
# 1     276
# Name: count, dtype: int64
# Index([0, 1], dtype='int64', name='heart_disease')

# %%
a=df['ever_married'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.bar(x,y)
plt.title("Marital Status Distribution of Patients",fontdict={'family':'Serif','weight':'bold','size':18})
plt.xlabel("Marital Status")
plt.ylabel("Number of Patients")
plt.show()
# Out:
# ever_married
# Yes    3353
# No     1757
# Name: count, dtype: int64
# Index(['Yes', 'No'], dtype='object', name='ever_married')

# %%
a=df['ever_married'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.pie(y,labels=x)
plt.title("Marital Status Distribution of Patients",fontdict={'family':'Serif','weight':'bold','size':18})
plt.show()
# Out:
# ever_married
# Yes    3353
# No     1757
# Name: count, dtype: int64
# Index(['Yes', 'No'], dtype='object', name='ever_married')

# %%
a=df['Residence_type'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.bar(x,y)
plt.title("Residence Type Distribution of Patients",fontdict={'family':'Serif','weight':'bold','size':18})
plt.xlabel("Residence Type (Urban / Rural)")
plt.ylabel("Number of Patients")
plt.show()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64
# Index(['Urban', 'Rural'], dtype='object', name='Residence_type')

# %%
a=df['Residence_type'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.pie(y,labels=x)
plt.title("Residence Type Distribution of Patients",fontdict={'family':'Serif','weight':'bold','size':18})
plt.show()
# Out:
# Residence_type
# Urban    2596
# Rural    2514
# Name: count, dtype: int64
# Index(['Urban', 'Rural'], dtype='object', name='Residence_type')

# %%
a=df['smoking_status'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.bar(x,y)
plt.title("Smoking Status Distribution of Patients",
          fontdict={'family':'Serif','weight':'bold','size':18})
plt.xlabel("Smoking Status")
plt.ylabel("Number of Patients")
plt.show()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64
# Index(['never smoked', 'Unknown', 'formerly smoked', 'smokes'], dtype='object', name='smoking_status')

# %%
a=df['smoking_status'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.pie(y,labels=x)
plt.title("Smoking Status Distribution of Patients",
          fontdict={'family':'Serif','weight':'bold','size':18})
plt.show()
# Out:
# smoking_status
# never smoked       1892
# Unknown            1544
# formerly smoked     885
# smokes              789
# Name: count, dtype: int64
# Index(['never smoked', 'Unknown', 'formerly smoked', 'smokes'], dtype='object', name='smoking_status')

# %%
a=df['stroke'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.bar(x,y)
plt.title("Stroke Occurrence Distribution Among Patients",
          fontdict={'family':'Serif','weight':'bold','size':18})
plt.xlabel("Stroke Status (0 = No, 1 = Yes)")
plt.ylabel("Number of Patients")

plt.show()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64
# Index([0, 1], dtype='int64', name='stroke')

# %%
a=df['stroke'].value_counts()
print(a)
x=a.index
print(x)
y=a.values
plt.pie(y,labels=x)
plt.title("Stroke Occurrence Distribution Among Patients",
          fontdict={'family':'Serif','weight':'bold','size':18})
plt.show()
# Out:
# stroke
# 0    4861
# 1     249
# Name: count, dtype: int64
# Index([0, 1], dtype='int64', name='stroke')
